# %%
import module1
import nltk
import numpy as np
import pandas as pd
import time

from sklearn import preprocessing

from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
filename = 'bank_train'
df = module1.read_df_from_csv(filename)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('russian')
#we can add stop words

import pymorphy2
def tokenize(text):
    text = text.lower()
    text_list = nltk.word_tokenize(text)
    morph = pymorphy2.MorphAnalyzer()
    text_list = [word for word in text_list if word[0] != '@' and len(word) > 1 and word.isalpha()]
    text_list = [morph.parse(word)[0].normal_form for word in text_list]
    return text_list

# %%
#tf-idf vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
j = 0
token_list = [i for i in df['text']]
tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words=stop_words)
tfs = tfidf.fit_transform(token_list)

# %%
#countVectorizer
start_time = time.time()
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=1, tokenizer=tokenize, stop_words=stop_words)
tfs4vec = vectorizer.fit_transform(token_list)
t = int(time.time() - start_time)
print ('TIME: {0}m {1}sec'.format(t / 60, t % 60))
# Out:
# TIME: 10m 15sec

# %%
def df_filter(_df, _tfs, corporation):
    x_arr = []
    y_arr = []
    for i in range(len(_df)):
        label = _df[corporation][i]
        if label == '0' or label == '-1' or label == '1' or label == 0.0 or label == -1.0 or label == 1.0:
            x_arr.append(_tfs[i].toarray()[0])
            y_arr.append(int(label))
    X = np.array(x_arr)
    y = np.array(y_arr)
    print (len(X))
    print (len(y))
    return X, y

# %%
def df_filter4(_df, _tfs, corporation):
    x_arr = []
    y_arr = []
    for i in range(len(_df)):
        label = _df[corporation][i]
        if label == '0' or label == '-1' or label == '1' or label == 0.0 or label == -1.0 or label == 1.0:
            x_arr.append(preprocessing.normalize(_tfs[i].toarray()[0]))
            y_arr.append(int(label))
    X = np.array(x_arr)
    y = np.array(y_arr)
    print (len(X))
    print (len(y))
    return X, y

# %%
X, y = df_filter(_df = df, _tfs = tfs, corporation = 'mts')
X4, y4 = df_filter(_df = df, _tfs = tfs4vec, corporation = 'mts')
# Out:
# 2005
# 2005
# 2005
# 2005
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-8622b0ee8f68> in <module>()
#       1 X, y = df_filter(_df = df, _tfs = tfs, corporation = 'mts')
#       2 X4, y4 = df_filter(_df = df, _tfs = tfs4vec, corporation = 'mts')
# ----> 3 X.features
#
# AttributeError: 'numpy.ndarray' object has no attribute 'features'

# %%
df_test
# Out:
#       Unnamed: 0  beeline        date  komstar  megafon  mts  rostelecom  \
# 0              1       -1  1386326071      NaN      NaN  NaN         NaN
# 1              2        1  1386326224      NaN      NaN  NaN         NaN
# 2              3        1  1386326461      NaN      NaN  NaN         NaN
# 3              4        0  1386327729      NaN      NaN  NaN         NaN
# 4              5        1  1386328678      NaN      NaN  NaN         NaN
# 5              6        1  1386329811      NaN      NaN  NaN         NaN
# 6              7        0  1386330246      NaN      NaN  NaN         NaN
# 7              8        1  1386331062      NaN      NaN  NaN         NaN
# 8              9        0  1386331134      NaN      NaN  NaN         NaN
# 9             10        0  1386331297      NaN      NaN  NaN         NaN
# 10            11        1  1386331328      NaN      NaN    1         NaN
# 11            12        0  1386331394      NaN      NaN  NaN         NaN
# 12            13        0  1386331414      NaN      NaN  NaN         NaN
# 13            14        0  1386331571      NaN      NaN  NaN         NaN
# 14            15       -1  1386331604      NaN      NaN  NaN         NaN
# 15            17        0  1386332050      NaN      NaN    0         NaN
# 16            18        0  1386332150      NaN      NaN    0         NaN
# 17            20        1  1386358849      NaN      NaN  NaN         NaN
# 18            21        0  1386360632      NaN      NaN  NaN         NaN
# 19            22        1  1386361687      NaN      NaN  NaN         NaN
# 20            23       -1  1386362224      NaN      NaN  NaN         NaN
# 21            24        0  1386363612      NaN      NaN  NaN         NaN
# 22            25        0  1386363922      NaN      NaN  NaN         NaN
# 23            26        0  1386364135      NaN      NaN  NaN         NaN
# 24            27        1  1386367959      NaN      NaN  NaN         NaN
# 25            28        0  1386368038      NaN      NaN  NaN         NaN
# 26            29        0  1386368077      NaN      NaN  NaN         NaN
# 27            30       -1  1386368231      NaN      NaN  NaN         NaN
# 28            31       -1  1386368295      NaN      NaN  NaN         NaN
# 29            32       -1  1386368294      NaN      NaN  NaN         NaN
# ...          ...      ...         ...      ...      ...  ...         ...
# 3815        4945      NaN  1387906813      NaN      NaN    0         NaN
# 3816        4951      NaN  1387910663      NaN      NaN    0         NaN
# 3817        4953      NaN  1387911841      NaN      NaN    0         NaN
# 3818        4954      NaN  1387911986      NaN      NaN    0         NaN
# 3819        4956      NaN  1387913578      NaN      NaN    0         NaN
# 3820        4958      NaN  1387940938      NaN      NaN    0         NaN
# 3821        4960      NaN  1387941226      NaN      NaN    0         NaN
# 3822        4961      NaN  1387941560      NaN      NaN    0         NaN
# 3823        4964      NaN  1387942816      NaN      NaN    0         NaN
# 3824        4965      NaN  1387943033      NaN      NaN   -1         NaN
# 3825        4966      NaN  1387943055      NaN      NaN   -1         NaN
# 3826        4973      NaN  1387944590      NaN      NaN    0         NaN
# 3827        4974      NaN  1387944681      NaN      NaN    0         NaN
# 3828        4976      NaN  1387945082      NaN      NaN    0         NaN
# 3829        4978      NaN  1387945286      NaN      NaN   -1         NaN
# 3830        4979      NaN  1387945678      NaN      NaN    0         NaN
# 3831        4981      NaN  1387946079      NaN      NaN    0         NaN
# 3832        4982      NaN  1387946295      NaN      NaN    0         NaN
# 3833        4984      NaN  1387946678      NaN      NaN    0         NaN
# 3834        4985      NaN  1387947107      NaN      NaN    0         NaN
# 3835        4988      NaN  1387948189      NaN      NaN    0         NaN
# 3836        4989      NaN  1387949049      NaN      NaN    0         NaN
# 3837        4990      NaN  1387949375      NaN      NaN    0         NaN
# 3838        4991      NaN  1387949563      NaN      NaN    0         NaN
# 3839        4993      NaN  1387950221      NaN      NaN    0         NaN
# 3840        4996      NaN  1387950700      NaN      NaN    0         NaN
# 3841        4997      NaN  1387951390      NaN      NaN    1         NaN
# 3842        4998      NaN  1387951488      NaN      NaN    0         NaN
# 3843        4999      NaN  1387951797      NaN      NaN    0         NaN
# 3844        5000      NaN  1387952043      NaN        0    0         NaN
#
#       skylink  tele2                                               text  \
# 0         NaN    NaN  RT @vestihitech: Лайфхак от Билайн: как зарабо...
# 1         NaN    NaN  RT @yablochno_com: iPhone 5S и 5C заработали в...
# 2         NaN    NaN  RT @HAPKOTNKN: «Билайн» включил LTE для владел...
# 3         NaN    NaN  @domrist =&gt; Указанную информацию, пожалуйст...
# 4         NaN    NaN  Ура! Теперь заработает#Lte#4g#beeline#nanosim#...
# 5         NaN    NaN  RT @wylsacom: Запуск 4G от Билайн ознаменовалс...
# 6         NaN    NaN                              @Beeline_RUS Отправил
# 7         NaN    NaN  Воу-воу. Не ожидал от #beeline http://t.co/cu3...
# 8         NaN    NaN    Кто нить уже тестировал LET на #beeline в #уфе?
# 9         NaN    NaN  @Leosnowy Кстати я помню ты еще ТОГДА мне прод...
# 10        NaN    NaN  RT @wylsacom: Но в силу поддержки разных часто...
# 11        NaN    NaN  RT @SPotresov: Жёнушка отожгла: Билайну надо в...
# 12        NaN    NaN            @Beeline_RUS @volgaport Заволновались!)
# 13        NaN    NaN  Зрители "Билайн ТВ" будут самостоятельно созда...
# 14        NaN    NaN   Что-то я ни хрена с этим пчелайном не доганяю %)
# 15        NaN    NaN  жена стала часто получать смски от MTS... я бы...
# 16        NaN    NaN  @AppleJesus скажи, теперь можно брать 5s a1533...
# 17        NaN    NaN  «Билайн» первым запустил мобильную связь в 150...
# 18        NaN    NaN  @m_khoroshev и ради этого я пытаюсь достать си...
# 19        NaN    NaN              LTE Билайна заработал на iPhone 5s/5c
# 20        NaN    NaN  RT @SadieOcasey: ФАС может оштрафовать ВымпелК...
# 21        NaN    NaN  dir_300nrub5 ошибка подключения по вай фай бил...
# 22        NaN    NaN  @sbezrodnaya а дурная голова, когда что-то не ...
# 23        NaN    NaN                   билайн.ру http://t.co/YOHK6Dvi05
# 24        NaN    NaN  Все-таки постепенно контракты у мобильных опер...
# 25        NaN    NaN  безлимитная опера мини билайн http://t.co/0MOD...
# 26        NaN    NaN  http://t.co/HKBNUYJuTO как узнать номер на айп...
# 27        NaN    NaN                                      ёбаный билайн
# 28        NaN    NaN  придётся сегодня опять идти разбираться, в офи...
# 29        NaN    NaN  ФАС может оштрафовать «ВымпелКом» и Apple из-з...
# ...       ...    ...                                                ...
# 3815      NaN    NaN  Услугами передачи данных МТС на Юге России пол...
# 3816      NaN    NaN  Немного статы и прогнозов по продуктам Apple и...
# 3817      NaN    NaN  @ru_mts  Хотела погасить до конца  остаток обе...
# 3818      NaN    NaN  RT @Loginlag: #петербург мтс http://t.co/kGCY2...
# 3819      NaN    NaN  МТС - новый тариф ПРЕЗИДЕНТСКИЙ: Первые 10 лет...
# 3820      NaN    NaN             Как и предполагал ДТП возле МТС Банка.
# 3821      NaN    NaN  скачать на андроид мтс pro веселую ферму 3 рус...
# 3822      NaN    NaN  как удалить все настройки с андроид мтс нео вр...
# 3823      NaN    NaN  можно ли перепрошить android 2.2 mts http://t....
# 3824      NaN    NaN                          Вот МТС такие овцы, бесят
# 3825      NaN    NaN  МТС обломщики, именно по магадану в их магазин...
# 3826      NaN    NaN  @DenisKazan зайди в МТС там 7-ми значный номер...
# 3827      NaN    NaN  как пользоваться андроид мтс http://t.co/LkAVR...
# 3828      NaN    NaN  скачать говорящего кота на андроид мтс http://...
# 3829      NaN    NaN  Вот вот тоже ощущения...;( RT @podakuni: Чувст...
# 3830      NaN    NaN  @ru_mts встань в любом месте города !\nвчера е...
# 3831      NaN    NaN  если вирус повредил память телефона мтс андрои...
# 3832      NaN    NaN    тарифы мтс для андроидов http://t.co/la4mZRgXdx
# 3833      NaN    NaN  драйвера модема 3g мтс для android http://t.co...
# 3834      NaN    NaN  talking tom для андроида мтс http://t.co/loaie...
# 3835      NaN    NaN  фильмы бесплатно для андроид мтс http://t.co/z...
# 3836      NaN    NaN  модэм е-1550 мтс потключить андроид 2.1 китай ...
# 3837      NaN    NaN  @LerikPerik, если не затруднит, напишите номер...
# 3838      NaN    NaN  настройка gprs android мтс http://t.co/LPo6mafkD3
# 3839      NaN    NaN  @AzamatUfa, если ситуация повторится, просим н...
# 3840      NaN    NaN  @kukusru, данный вопрос находится в компетенци...
# 3841      NaN    NaN                            МТС уже все починили :)
# 3842      NaN    NaN  @TheZavitaev, на данный момент ситуация сохран...
# 3843      NaN    NaN  3g мтс подоидет к андроиду http://t.co/ZVzFU06p6f
# 3844      NaN    NaN  @A1daron @AppleInsider_ru нет, именно после JB...
#
#                   twitid
# 0     408907296950218752
# 1     408907938406072320
# 2     408908931600498688
# 3     408914249545555968
# 4     408918232146673664
# 5     408922982565048320
# 6     408924808651743232
# 7     408928230838906880
# 8     408928534930128896
# 9     408929217112702976
# 10    408929347987570688
# 11    408929624828428288
# 12    408929707074150401
# 13    408930367157338112
# 14    408930505623891968
# 15    408932374651490304
# 16    408932793394413568
# 17    409044779532439552
# 18    409052255745482752
# 19    409056682778845184
# 20    409058935048790016
# 21    409064755887112192
# 22    409066055500189697
# 23    409066951382958080
# 24    409082988493033472
# 25    409083317875916800
# 26    409083483848724480
# 27    409084127585906689
# 28    409084397040590848
# 29    409084394595692546
# ...                  ...
# 3815  415537410374504448
# 3816  415553559757737984
# 3817  415558498848882688
# 3818  415559107354304512
# 3819  415565785994514432
# 3820  415680538759168000
# 3821  415681748182114304
# 3822  415683150119833600
# 3823  415688418501197825
# 3824  415689329064017920
# 3825  415689420021317632
# 3826  415695858819424256
# 3827  415696240706207744
# 3828  415697919681908736
# 3829  415698777010601984
# 3830  415700420187934720
# 3831  415702103026192384
# 3832  415703007917907970
# 3833  415704617582727168
# 3834  415706416637149184
# 3835  415710954446286848
# 3836  415714560796942336
# 3837  415715925917057024
# 3838  415716717826801664
# 3839  415719475074170880
# 3840  415721486951796736
# 3841  415724380446941184
# 3842  415724789827768321
# 3843  415726086568157184
# 3844  415727116807077888
#
# [3845 rows x 11 columns]

# %%
df_test = module1.read_df_from_csv('bank_test_etalon')

# %%
X = np.vstack((X, X_test[976:]))
X_test = X_test[:976]
y = np.concatenate((y,y_test[976:]))
y_test = y_test[:976]
X4 = np.vstack((X4, X4_test[976:]))
X4_test = X4_test[:976]
y4 = np.concatenate((y4,y4_test[976:]))
y4_test = y4_test[:976]

print X.shape
print y.shape
print '~~~'
print X_test.shape
print y_test.shape
print '!!!!!!!!!'
print X4.shape
print y4.shape
print '~~~~~'
print X4_test.shape
print y4_test.shape
# Out:
# (3895, 4373)
# (3895,)
# ~~~
# (976, 4373)
# (976,)
# !!!!!!!!!
# (3895, 4373)
# (3895,)
# ~~~~~
# (976, 4373)
# (976,)

# %%
from sklearn.naive_bayes import MultinomialNB
#Create a Multiline Classifier for sberbank
modelM = MultinomialNB()
modelM.fit(X, y)
print('~~~')
modelM4 = MultinomialNB()
modelM4.fit(X4, y4)
# Out:
# ~~~
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_predict = modelM.predict(X_test)
print ('Multinominal Naive Bayes')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# Multinominal Naive Bayes
# f-macro: 0.348657748658
# f-micro: 0.683401639344
# accurace: 0.683401639344

# %%
y_predict = modelM4.predict(X4_test)
print ('Multinominal Naive Bayes 4')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# Multinominal Naive Bayes 4
# f-macro: 0.347000733936
# f-micro: 0.578893442623
# accurace: 0.578893442623

# %%
modelSVM = SVC()
modelSVM.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
modelSVM4 = SVC()
modelSVM4.fit(X4, y4)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_predict = modelSVM.predict(X_test)
print ('SVM')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# SVM
# f-macro: 0.298434257687
# f-micro: 0.810450819672
# accurace: 0.810450819672

# %%
y_predict = modelSVM4.predict(X4_test)
print ('SVM4')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# SVM4
# f-macro: 0.298434257687
# f-micro: 0.810450819672
# accurace: 0.810450819672

# %%
modelSVM = SVC(kernel='linear')
modelSVM.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_predict = modelSVM.predict(X_test)
print ('SVM linear')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# SVM linear
# f-macro: 0.35358572005
# f-micro: 0.64856557377
# accurace: 0.64856557377

# %%
modelSVM4 = SVC(kernel='linear')
modelSVM4.fit(X4, y4)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_predict = modelSVM4.predict(X4_test)
print ('SVM4 linear')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# SVM4 linear
# f-macro: 0.348507952461
# f-micro: 0.608606557377
# accurace: 0.608606557377

# %%
modelKNN = KNeighborsClassifier(n_neighbors=10)
modelKNN.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=10, p=2, weights='uniform')

# %%
modelKNN4 = KNeighborsClassifier(n_neighbors=10)
modelKNN4.fit(X4, y4)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=10, p=2, weights='uniform')

# %%
y_predict = modelKNN.predict(X_test)
print ('kNN: 10')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# kNN: 10
# f-macro: 0.352290731601
# f-micro: 0.657786885246
# accurace: 0.657786885246

# %%
y_predict = modelKNN4.predict(X4_test)
print ('kNN4: 10')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# kNN4: 10
# f-macro: 0.370247153954
# f-micro: 0.686475409836
# accurace: 0.686475409836

# %%
model5NN = KNeighborsClassifier(n_neighbors=5)
model5NN.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=5, p=2, weights='uniform')

# %%
model5NN4 = KNeighborsClassifier(n_neighbors=5)
model5NN4.fit(X4, y4)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=5, p=2, weights='uniform')

# %%
y_predict = model5NN.predict(X_test)
print ('kNN: 5')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# kNN: 5
# f-macro: 0.346785100872
# f-micro: 0.63012295082
# accurace: 0.63012295082

# %%
y_predict = model5NN4.predict(X4_test)
print ('kNN4: 5')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# kNN4: 5
# f-macro: 0.33245410488
# f-micro: 0.614754098361
# accurace: 0.614754098361

# %%
model30NN = KNeighborsClassifier(n_neighbors=30)
model30NN.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=30, p=2, weights='uniform')

# %%
model30NN4 = KNeighborsClassifier(n_neighbors=30)
model30NN4.fit(X4, y4)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=30, p=2, weights='uniform')

# %%
y_predict = model30NN.predict(X_test)
print ('kNN: 30')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# kNN: 30
# f-macro: 0.345358726008
# f-micro: 0.69262295082
# accurace: 0.69262295082

# %%
y_predict = model30NN4.predict(X4_test)
print ('kNN4: 30')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# kNN4: 30
# f-macro: 0.344685161495
# f-micro: 0.71106557377
# accurace: 0.71106557377

# %%
model3NN = KNeighborsClassifier(n_neighbors=3)
model3NN.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=3, p=2, weights='uniform')

# %%
model3NN4 = KNeighborsClassifier(n_neighbors=3)
model3NN4.fit(X4, y4)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=3, p=2, weights='uniform')

# %%
y_predict = model3NN.predict(X_test)
print ('kNN: 3')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# kNN: 3
# f-macro: 0.363558562356
# f-micro: 0.607581967213
# accurace: 0.607581967213

# %%
y_predict = model3NN4.predict(X4_test)
print ('kNN4: 3')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# kNN4: 3
# f-macro: 0.340330673404
# f-micro: 0.585040983607
# accurace: 0.585040983607

# %%
model7NN = KNeighborsClassifier(n_neighbors=7)
model7NN.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=7, p=2, weights='uniform')

# %%
model7NN4 = KNeighborsClassifier(n_neighbors=7)
model7NN4.fit(X4, y4)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=7, p=2, weights='uniform')

# %%
y_predict = model7NN.predict(X_test)
print ('kNN: 7')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# kNN: 7
# f-macro: 0.360618068305
# f-micro: 0.650614754098
# accurace: 0.650614754098

# %%
y_predict = model7NN4.predict(X4_test)
print ('kNN4: 7')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# kNN4: 7
# f-macro: 0.353683445736
# f-micro: 0.657786885246
# accurace: 0.657786885246

# %%
modelTreeMax = DecisionTreeClassifier(max_depth = 5)
modelTree = DecisionTreeClassifier()

modelTreeMax.fit(X, y)
modelTree.fit(X, y)
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best')

# %%
modelTreeMax4 = DecisionTreeClassifier(max_depth = 5)
modelTree4 = DecisionTreeClassifier()

modelTreeMax4.fit(X4, y4)
modelTree4.fit(X4, y4)
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best')

# %%
y_predict = modelTreeMax.predict(X_test)
print ('DecisionTree depth=5:')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))

y_predict = modelTree.predict(X_test)
print ('DecisionTree:')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# DecisionTree depth=5:
# f-macro: 0.332052227374
# f-micro: 0.718237704918
# accurace: 0.718237704918
# DecisionTree:
# f-macro: 0.321691393548
# f-micro: 0.544057377049
# accurace: 0.544057377049

# %%
y_predict = modelTreeMax4.predict(X4_test)
print ('DecisionTree4 depth=5:')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))

y_predict = modelTree4.predict(X4_test)
print ('DecisionTree4:')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# DecisionTree4 depth=5:
# f-macro: 0.340711350518
# f-micro: 0.702868852459
# accurace: 0.702868852459
# DecisionTree4:
# f-macro: 0.337527189684
# f-micro: 0.555327868852
# accurace: 0.555327868852

# %%
modelAdaBoost = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=600,
    learning_rate=1)
modelAdaBoost.fit(X, y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=2, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best'),
#           learning_rate=1, n_estimators=600, random_state=None)

# %%
modelAdaBoost4 = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
modelAdaBoost4.fit(X4, y4)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=2, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best'),
#           learning_rate=1, n_estimators=600, random_state=None)

# %%
y_predict = modelAdaBoost.predict(X_test)
print ('AdaBoost:')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# AdaBoost:
# f-macro: 0.335943415023
# f-micro: 0.582991803279
# accurace: 0.582991803279

# %%
y_predict = modelAdaBoost4.predict(X4_test)
print ('AdaBoost4:')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# AdaBoost4:
# f-macro: 0.340123816474
# f-micro: 0.578893442623
# accurace: 0.578893442623

# %%
modelAdaBoost5 = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5), n_estimators=600,
    learning_rate=1)
modelAdaBoost5.fit(X, y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=5, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best'),
#           learning_rate=1, n_estimators=600, random_state=None)

# %%
modelAdaBoost5_4 = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5), n_estimators=600,
    learning_rate=1)
modelAdaBoost5_4.fit(X4, y4)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=5, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=None, splitter='best'),
#           learning_rate=1, n_estimators=600, random_state=None)

# %%
y_predict = modelAdaBoost5.predict(X_test)
print ('AdaBoost with max depth 5:')
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('accurace: {0}'.format(accuracy_score(y_test, y_predict)))
# Out:
# AdaBoost with max depth 5:
# f-macro: 0.330431365997
# accurace: 0.555327868852

# %%
y_predict = modelAdaBoost5_4.predict(X4_test)
print ('AdaBoost4 with max depth 5:')
print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
print ('accurace: {0}'.format(accuracy_score(y4_test, y_predict)))
# Out:
# AdaBoost4 with max depth 5:
# f-macro: 0.349515413041
# accurace: 0.572745901639

# %%
companies = ['skylink']
for companie in companies:
    print('!!!!!!!!!!!!!!!!!')
    print(companie)
    print ('~~~~~~~~~~~~~~~~~')
    
    X, y = df_filter(_df = df, _tfs = tfs, corporation = companie)
    X4, y4 = df_filter(_df = df, _tfs = tfs4vec, corporation = companie)
    X_test, y_test = df_filter(_df = df_test, _tfs = tfs, corporation = companie)
    X4_test, y4_test = df_filter(_df = df_test, _tfs = tfs4vec, corporation = companie)
    
    index = int((X.shape[0] + X_test.shape[0]) * 0.2)
    if (index < X_test.shape[0]):
        X = np.vstack((X, X_test[index:]))
        X_test = X_test[:index]
        y = np.concatenate((y,y_test[index:]))
        y_test = y_test[:index]
        X4 = np.vstack((X4, X4_test[index:]))
        X4_test = X4_test[:index]
        y4 = np.concatenate((y4,y4_test[index:]))
        y4_test = y4_test[:index]
    
    print ('DATA SIZE: TRAIN = {0}, TEST= {1}'.format(X.shape[0], X_test.shape[0]))
    print ('Naive Bayes: ')
    start_time = time.time()
    model = MultinomialNB()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    t = int(time.time() - start_time)
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = MultinomialNB()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('SVM: ')
    start_time = time.time()
    model = SVC()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = SVC()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))  
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('SVM linear kernel: ')
    start_time = time.time()
    model = SVC(kernel = 'linear')
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = SVC(kernel = 'linear')
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 10: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=10)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=10)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 5: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=5)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=5)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 3: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=3)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=3)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 7: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=7)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=7)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 30: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=30)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=30)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('Decision Tree: ')
    start_time = time.time()
    model = DecisionTreeClassifier()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  DecisionTreeClassifier()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('Decision Tree max depth = 5: ')
    start_time = time.time()
    model = DecisionTreeClassifier(max_depth = 5)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  DecisionTreeClassifier(max_depth = 5)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('AdaBoost DecisionTree max_depth = 2, n = 100: ')
    start_time = time.time()
    model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
# Out:
# !!!!!!!!!!!!!!!!!
# skylink
# ~~~~~~~~~~~~~~~~~
# 12
# 12
# 12
# 12
# 0
# 0
# 0
# 0
# DATA SIZE: TRAIN = 12, TEST= 0
# Naive Bayes:
# fit time = 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-1caa36398b62> in <module>()
#      29     print ('fit time = {0} {1}'.format(t / 60, t % 60))
#      30     start_time = time.time()
# ---> 31     y_predict = model.predict(X_test)
#      32     print ('predict time = {0} {1}'.format(t / 60, t % 60))
#      33     print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
#
# /home/parkinmsu/anaconda/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in predict(self, X)
#      60             Predicted target values for X
#      61         """
# ---> 62         jll = self._joint_log_likelihood(X)
#      63         return self.classes_[np.argmax(jll, axis=1)]
#      64
#
# /home/parkinmsu/anaconda/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in _joint_log_likelihood(self, X)
#     439         """Calculate the posterior log probability of the samples X"""
#     440         X = atleast2d_or_csr(X)
# --> 441         return (safe_sparse_dot(X, self.feature_log_prob_.T)
#     442                 + self.class_log_prior_)
#     443
#
# /home/parkinmsu/anaconda/lib/python2.7/site-packages/sklearn/utils/extmath.pyc in safe_sparse_dot(a, b, dense_output)
#     178         return ret
#     179     else:
# --> 180         return fast_dot(a, b)
#     181
#     182
#
# ValueError: shapes (1,0) and (7306,2) not aligned: 0 (dim 1) != 7306 (dim 0)

# %%
X_all, y_all = df_filter(_df = df, _tfs = tfs, corporation = 'sberbank')
X4_all, y4_all = df_filter(_df = df, _tfs = tfs4vec, corporation = 'sberbank')
X_test_all, y_test_all = df_filter(_df = df_test, _tfs = tfs, corporation = 'sberbank')
X4_test_all, y4_test_all = df_filter(_df = df_test, _tfs = tfs4vec, corporation = 'sberbank')
companies = ['vtb', 'gazprom', 'alfabank', 'raiffeisen', 'uralsib', 'rshb']
for companie in companies:
    print('!!!!!!!!!!!!!!!!!')
    print(companie)
    print ('~~~~~~~~~~~~~~~~~')
    
    X, y = df_filter(_df = df, _tfs = tfs, corporation = companie)
    X_all = np.vstack((X_all, X))
    y_all = np.concatenate((y_all,y))
    X4, y4 = df_filter(_df = df, _tfs = tfs4vec, corporation = companie)
    X4_all = np.vstack((X4_all, X4))
    y4_all = np.concatenate((y4_all,y4))
    X_test, y_test = df_filter(_df = df_test, _tfs = tfs, corporation = companie)
    X_test_all = np.vstack((X_test_all, X_test))
    y_test_all = np.concatenate((y_test_all,y_test))
    X4_test, y4_test = df_filter(_df = df_test, _tfs = tfs4vec, corporation = companie)
    X4_test_all = np.vstack((X4_test_all, X4_test))
    y4_test_all = np.concatenate((y4_test_all,y4_test))
    

def calculation(X, y, X_test, y_test, X4, y4, X4_test, y4_test):    
    index = int((X.shape[0] + X_test.shape[0]) * 0.2)
    if (index < X_test.shape[0]):
        X = np.vstack((X, X_test[index:]))
        X_test = X_test[:index]
        y = np.concatenate((y,y_test[index:]))
        y_test = y_test[:index]
        X4 = np.vstack((X4, X4_test[index:]))
        X4_test = X4_test[:index]
        y4 = np.concatenate((y4,y4_test[index:]))
        y4_test = y4_test[:index]
    
    print ('DATA SIZE: TRAIN = {0}, TEST= {1}'.format(X.shape[0], X_test.shape[0]))
    print ('Naive Bayes: ')
    start_time = time.time()
    model = MultinomialNB()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    t = int(time.time() - start_time)
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = MultinomialNB()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('SVM: ')
    start_time = time.time()
    model = SVC()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = SVC()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))  
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('SVM linear kernel: ')
    start_time = time.time()
    model = SVC(kernel = 'linear')
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = SVC(kernel = 'linear')
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 10: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=10)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=10)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 5: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=5)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=5)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 3: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=3)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=3)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 7: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=7)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=7)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 30: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=30)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=30)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('Decision Tree: ')
    start_time = time.time()
    model = DecisionTreeClassifier()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  DecisionTreeClassifier()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('Decision Tree max depth = 5: ')
    start_time = time.time()
    model = DecisionTreeClassifier(max_depth = 5)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  DecisionTreeClassifier(max_depth = 5)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('AdaBoost DecisionTree max_depth = 2, n = 100: ')
    start_time = time.time()
    model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
# Out:
# 3895
