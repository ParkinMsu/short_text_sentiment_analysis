# %%
import nltk
import numpy as np
import pandas as pd
import time

from sklearn import preprocessing

from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from os import path

# %%
subdir = './datasets/twitter/'
filename = 'bank_train'
df = pd.read_csv(path.join(subdir,filename))
df_test = pd.read_csv(path.join(subdir, 'bank_test_etalon'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-99746046f91f> in <module>()
#       1 subdir = './datasets/twitter/'
#       2 filename = 'bank_train'
# ----> 3 df = pd.read_csv(path.join(subdir,filename))
#       4 df_test = pd.read_csv(path.join(subdir, 'bank_test_etalon'))
#
# NameError: name 'path' is not defined

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('russian')
#we can add stop words

import pymorphy2
def tokenize(text):
    text = text.lower()
    text_list = nltk.word_tokenize(text)
    morph = pymorphy2.MorphAnalyzer()
    text_list = [word for word in text_list if word[0] != '@' and len(word) > 1 and word.isalpha()]
    text_list = [morph.parse(word)[0].normal_form for word in text_list]
    return text_list

# %%
#tf-idf vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
j = 0
token_list = [i for i in df['text']]
tfidf = TfidfVectorizer(tokenizer=tokenize, stop_words=stop_words)
tfs = tfidf.fit_transform(token_list)

# %%
import ngram_vectorize
token_list = [ngram_vectorize.get_ngrams(i,n=3,is_join=True) for i in df['text']]
tfidf = TfidfVectorizer()
tfs = tfidf.fit_transform(token_list)

# %%
def df_filter(_df, _tfs, corporation):
    x_arr = []
    y_arr = []
    for i in range(len(_df)):
        label = _df[corporation][i]
        if label == '0' or label == '-1' or label == '1' or label == 0.0 or label == -1.0 or label == 1.0:
            x_arr.append(_tfs[i].toarray()[0])
            y_arr.append(int(label))
    X = np.array(x_arr)
    y = np.array(y_arr)
    print (len(X))
    print (len(y))
    return X, y

# %%
df
# Out:
#       Unnamed: 0 alfabank        date gazprom raiffeisen rshb sberbank  \
# 0              1        0  1406224554     NaN        NaN  NaN      NaN
# 1              2      NaN  1406224691     NaN        NaN  NaN      NaN
# 2              3      NaN  1406224798     NaN          0  NaN      NaN
# 3              4      NaN  1406225412     NaN        NaN  NaN        0
# 4              5      NaN  1406226283     NaN        NaN  NaN        1
# 5              6      NaN  1406226450     NaN        NaN  NaN      NaN
# 6              7      NaN  1406226505     NaN        NaN  NaN      NaN
# 7              8      NaN  1406226607     NaN        NaN  NaN       +-
# 8              9      NaN  1406226960     NaN        NaN  NaN        0
# 9             10      NaN  1406226982     NaN        NaN    0      NaN
# 10            11      NaN  1406227218     NaN        NaN  NaN      NaN
# 11            12      NaN  1406227218     NaN         -1  NaN      NaN
# 12            13        0  1406227462     NaN        NaN  NaN      NaN
# 13            14      NaN  1406227462     NaN        NaN    0      NaN
# 14            15      NaN  1406227585     NaN        NaN  NaN      NaN
# 15            16      NaN  1406228494     NaN        NaN  NaN       -1
# 16            17      NaN  1406228524     NaN        NaN  NaN        0
# 17            18      NaN  1406228524       0        NaN  NaN      NaN
# 18            19      NaN  1406228544     NaN        NaN  NaN        0
# 19            20      NaN  1406228795     NaN        NaN  NaN       -1
# 20            21      NaN  1406228880     NaN        NaN    0      NaN
# 21            22      NaN  1406232599     NaN        NaN  NaN      NaN
# 22            23      NaN  1406257672     NaN        NaN  NaN      NaN
# 23            24      NaN  1406257673     NaN        NaN    0      NaN
# 24            25      NaN  1406258046     NaN        NaN  NaN      NaN
# 25            26      NaN  1406258181     NaN        NaN  NaN      NaN
# 26            27      NaN  1406258263       0        NaN  NaN      NaN
# 27            28      NaN  1406258476      -1        NaN  NaN      NaN
# 28            29        0  1406258508     NaN        NaN  NaN      NaN
# 29            30      NaN  1406258549     NaN          0  NaN      NaN
# ...          ...      ...         ...     ...        ...  ...      ...
# 4970        4971      NaN  1407886023     NaN        NaN    0      NaN
# 4971        4972      NaN  1407886076     NaN        NaN  NaN        0
# 4972        4973      NaN  1407886106     NaN        NaN  NaN      NaN
# 4973        4974      NaN  1407886422     NaN        NaN   -1      NaN
# 4974        4975      NaN  1407886475     NaN        NaN  NaN        0
# 4975        4976      NaN  1407886867     NaN        NaN  NaN      NaN
# 4976        4977      NaN  1407886909     NaN        NaN  NaN        0
# 4977        4978      NaN  1407887003     NaN        NaN  NaN      NaN
# 4978        4979      NaN  1407887207     NaN        NaN  NaN        0
# 4979        4980      NaN  1407887227     NaN          0  NaN      NaN
# 4980        4981      NaN  1407887301     NaN        NaN  NaN      NaN
# 4981        4982      NaN  1407887344     NaN        NaN  NaN        0
# 4982        4983      NaN  1407887543     NaN        NaN  NaN        0
# 4983        4984      NaN  1407887660     NaN        NaN  NaN      NaN
# 4984        4985      NaN  1407887671     NaN        NaN  NaN        0
# 4985        4986      NaN  1407887671     NaN        NaN  NaN        0
# 4986        4987      NaN  1407887682     NaN        NaN  NaN      NaN
# 4987        4988      NaN  1407887693     NaN        NaN  NaN        0
# 4988        4989      NaN  1407887768     NaN        NaN  NaN      NaN
# 4989        4990        0  1407887973     NaN        NaN  NaN      NaN
# 4990        4991      NaN  1407888059     NaN        NaN  NaN        0
# 4991        4992      NaN  1407888070     NaN          0  NaN      NaN
# 4992        4993      NaN  1407888080     NaN        NaN  NaN      NaN
# 4993        4994      NaN  1407888502     NaN        NaN    0      NaN
# 4994        4995      NaN  1407888514     NaN        NaN  NaN      NaN
# 4995        4996      NaN  1407888670     NaN        NaN  NaN        1
# 4996        4997      NaN  1407888870     NaN        NaN  NaN        0
# 4997        4998      NaN  1407888879     NaN        NaN  NaN        0
# 4998        4999      NaN  1407888993     NaN        NaN  NaN        0
# 4999        5000      NaN  1407889172     NaN        NaN  NaN        0
#
#                                                    text              twitid  \
# 0     http://t.co/YEVHuvVGA1 Взять кредит тюмень аль...  492367586156630000
# 1     Мнение о кредитной карте втб 24 http://t.co/SB...  492368160923070000
# 2     «Райффайзенбанк»: Снижение ключевой ставки ЦБ ...  492368608346260000
# 3     Современное состояние кредитного поведения в р...  492371181946030000
# 4     @sawik_shuster @YevhenS Главное чтоб банки СБЕ...  492374836564750000
# 5     http://t.co/Qr6JbSVTxY Оформить краткосрочный ...  492375537080600000
# 6     Самый выгодный автокредит в втб 24 http://t.co...  492375766907510000
# 7     Похоже завтра Сбербанк и ВТБ присоединяется к ...  492376193791190000
# 8     Кредит иногородним в москве сбербанк http://t....  492377674535680000
# 9     Кредитный калькулятор россельхозбанк чита http...  492377768232250000
# 10    http://t.co/h6r6GdBe4H Легко можно получить де...  492378757769220000
# 11    ДЕЛО -  На 1 млрд грн ушел в минус Райффайзен ...  492378758372800000
# 12    Део нексия в кредит в альфа банке http://t.co/...  492379779946260000
# 13    Россельхозбанк кредит стань фермером http://t....  492379780881590000
# 14    http://t.co/CuNsxVhAb0 Банк втб взять кредит 4...  492380298458710000
# 15    @ShtirliZ_ @Zhukova_olga @winzard @tereshenkov...  492384109483000000
# 16    Расчитать кредит сбер банк россии в москве htt...  492384237199580000
# 17    Кредит в газпром банке тула http://t.co/jqt7Nf...  492384237631570000
# 18    Кредитный калькулятор сбербанк россии http://t...  492384320926260000
# 19    @Umka_75 @Alfarius2012 @igor_sechin втб и сбер...  492385371649740000
# 20    http://t.co/Snn5WoPVcf Взять кредит строительс...  492385727242850000
# 21    Льготный период по кредитной карте втб 24 http...  492401325649690000
# 22    http://t.co/SqAiEPURl0 Казань банк втб 24 хочу...  492506491879190000
# 23    http://t.co/YtapffQchW Как взять кредит на раз...  492506495830200000
# 24    Оао банк втб северо запад в спб автокредит htt...  492508060754390000
# 25    http://t.co/6sKsurs9OH Оформить заявку на кред...  492508625018310000
# 26    http://t.co/v4cogwQQ1g Взять кредит в газпромб...  492508970482160000
# 27    Канада ввела санкции против Газпромбанка, ВЭБа...  492509863486840000
# 28    http://t.co/UYLSGYH8P6 Как взять денежный кред...  492509998220870000
# 29    Заявление на потребительский кредит в райффайз...  492510171139410000
# ...                                                 ...                 ...
# 4970  Россельхозбанк в пензе кредит http://t.co/Ut41...  499336290731830000
# 4971  Всё о Кредитах Как может появиться минусовый б...  499336512572380000
# 4972  RT @jehijaranupo: дадут ли мне кредит в втб 24...  499336638011810000
# 4973  Санкции против Россельхозбанка (РСХБ) создали ...  499337963097310000
# 4974  Потребительский кредит сбербанк казань http://...  499338187538720000
# 4975  Кредитная карта втб 24 в казани http://t.co/Ir...  499339829151560000
# 4976  RT @1apysy_: http://t.co/yNwUpkfKWA Qiwi Сберб...  499340006016550000
# 4977  http://t.co/h6HgKKiFBs втб 24 кредиты наличным...  499340399518180000
# 4978  Машина в кредит через сбербанк http://t.co/Enx...  499341257928620000
# 4979  Потребительский кредит в райффайзенбанке http:...  499341339977590000
# 4980  http://t.co/xtRdBqDxNG кредит наличными в втб ...  499341651119460000
# 4981  Купить автомобиль в кредит сбер банка http://t...  499341831248020000
# 4982  Как получить отсрочку по кредиту сбербанк http...  499342666031970000
# 4983     Банк втб 24 автокредиты http://t.co/phhQiME757  499343157436630000
# 4984  Калькулятор по кредитам сбербанк http://t.co/V...  499343203813050000
# 4985  Анкета по кредиту сбербанк россии http://t.co/...  499343204085680000
# 4986  Кредитный калькулятор по ипотеке втб 24 http:/...  499343248197170000
# 4987  Орск сбербанк потребительский кредит http://t....  499343293004910000
# 4988  RT @wosemymexaxy: взять кредит наличными в втб...  499343610786350000
# 4989  http://t.co/epYeZ6zLh9 автокредитование альфа ...  499344469435910000
# 4990  Ставки кредитования сбербанк россии http://t.c...  499344830066350000
# 4991  Кредит в райфайзене в самаре http://t.co/QKr0e...  499344875264150000
# 4992  Потребительский кредит калькулятор банк втб ht...  499344917496620000
# 4993  Россельхозбанк кредит на сельское хозяйство ht...  499346689460020000
# 4994  Банк москвы ярославль автокредит http://t.co/p...  499346737321250000
# 4995  Wiener Boerse решила оставить ВТБ и Сбербанк в...  499347392479890000
# 4996  Кредит на покупку недвижимости сбербанк http:/...  499348231122590000
# 4997  Как пользоваться кредитной картой visa сбербан...  499348270570040000
# 4998  @sberbank Оплатила 11.08.14 через моб.банк нал...  499348747995070000
# 4999  @sberbank зачислен. На сайте Сбербанка по отзы...  499349500054750000
#
#       uralsib  vtb
# 0         NaN  NaN
# 1         NaN    0
# 2         NaN  NaN
# 3         NaN  NaN
# 4         NaN    1
# 5         NaN  NaN
# 6         NaN    1
# 7         NaN   +-
# 8         NaN  NaN
# 9         NaN  NaN
# 10        NaN    1
# 11        NaN    0
# 12        NaN  NaN
# 13        NaN  NaN
# 14        NaN    0
# 15        NaN  NaN
# 16        NaN  NaN
# 17        NaN  NaN
# 18        NaN  NaN
# 19        NaN   -1
# 20        NaN  NaN
# 21        NaN    0
# 22        NaN    0
# 23        NaN  NaN
# 24        NaN    0
# 25        0.0  NaN
# 26        NaN  NaN
# 27        NaN  NaN
# 28        NaN  NaN
# 29        NaN  NaN
# ...       ...  ...
# 4970      NaN  NaN
# 4971      NaN  NaN
# 4972      NaN    0
# 4973      NaN  NaN
# 4974      NaN  NaN
# 4975      NaN    0
# 4976      NaN  NaN
# 4977      NaN    0
# 4978      NaN  NaN
# 4979      NaN  NaN
# 4980      NaN    0
# 4981      NaN  NaN
# 4982      NaN  NaN
# 4983      NaN    0
# 4984      NaN  NaN
# 4985      NaN  NaN
# 4986      NaN    0
# 4987      NaN  NaN
# 4988      NaN    0
# 4989      NaN  NaN
# 4990      NaN  NaN
# 4991      NaN  NaN
# 4992      NaN    0
# 4993      NaN  NaN
# 4994      NaN  NaN
# 4995      NaN    1
# 4996      NaN  NaN
# 4997      NaN  NaN
# 4998      NaN  NaN
# 4999      NaN  NaN
#
# [5000 rows x 11 columns]

# %%
companies = ['raiffeisen', 'alfabank', 'gazprom', 'raiffeisen', 'rshb', 'sberbank', 'uralsib', 'vtb']
X_train, y_train = df_filter(_df=df, _tfs=tfs, corporation=companies[0])
for companie in companies[1:]:
    X_curr, y_curr = df_filter(_df=df, _tfs=tfs, corporation=companie)
    X_train = np.append(X_train, X_curr, axis=0)
    y_train = np.append(y_train, y_curr)
# Out:
# 278
# 278
# 562
# 562
# 372
# 372
# 278
# 278
# 929
# 929
# 2038
# 2038
# 82
# 82
# 1257
# 1257

# %%
companies = ['raiffeisen', 'alfabank', 'gazprom', 'raiffeisen', 'rshb', 'sberbank', 'uralsib', 'vtb']
X_test, y_test = df_filter(_df=df_test, _tfs=tfs, corporation=companies[0])
for companie in companies[1:]:
    X_curr, y_curr = df_filter(_df=df_test, _tfs=tfs, corporation=companie)
    if len(X_curr) > 0:
        X_test = np.append(X_test, X_curr, axis=0)
        y_test = np.append(y_test, y_curr)
# Out:
# 150
# 150
# 536
# 536
# 137
# 137
# 150
# 150
# 99
# 99
# 2833
# 2833
# 60
# 60
# 651
# 651

# %%
print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print ('SVM: ')
start_time = time.time()
model = SVC()
model.fit(X_train, y_train)
t = int(time.time() - start_time)
print ('fit time = {0}m{1}sec'.format(t // 60, t % 60))
start_time = time.time()
y_predict = model.predict(X_test)
t = int(time.time() - start_time)
print ('predict time = {0}m{1}sec'.format(t // 60, t % 60))
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SVM:
# fit time = 4m39sec
# predict time = 4m5sec
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# f-macro: 0.2913363418303045
# f-micro: 0.776213171577123

# %%
import my_score
func= lambda x,y: my_score.f_macro(my_score.cound_diff(x,y))
print ('strange f score - {0}'.format(func(y_predict, y_test)))
# Out:
# strange f score - 0.4568404947086574

# %%
print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print ('Decision Tree: ')
start_time = time.time()
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
t = int(time.time() - start_time)
print ('fit time = {0} {1}'.format(t / 60, t % 60))
start_time = time.time()
y_predict = model.predict(X_test)
t = int(time.time() - start_time)
print ('predict time = {0} {1}'.format(t / 60, t % 60))
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('strange f score - {0}'.format(func(y_predict, y_test)))
print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print ('AdaBoost DecisionTree max_depth = 2, n = 100: ')
start_time = time.time()
model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5), n_estimators=100,
learning_rate=1)
model.fit(X_train, y_train)
t = int(time.time() - start_time)
print ('fit time = {0} {1}'.format(t / 60, t % 60))
start_time = time.time()
y_predict = model.predict(X_test)
t = int(time.time() - start_time)
print ('predict time = {0} {1}'.format(t / 60, t % 60))
print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
print ('strange f score - {0}'.format(func(y_predict, y_test)))
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Decision Tree:
# fit time = 0.1 6
# predict time = 0.0 0
# f-macro: 0.33241627485286734
# f-micro: 0.5853552859618717
# strange f score - 0.4235376068860566
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# AdaBoost DecisionTree max_depth = 2, n = 100:
# fit time = 3.2666666666666666 16
# predict time = 0.016666666666666666 1
# f-macro: 0.3298327295503713
# f-micro: 0.5899046793760832
# strange f score - 0.4228240132659454

# %%
#countVectorizer
start_time = time.time()
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=1, tokenizer=tokenize, stop_words=stop_words)
tfs4vec = vectorizer.fit_transform(token_list)
t = int(time.time() - start_time)
print ('TIME: {0}m {1}sec'.format(t / 60, t % 60))

# %%
companies = ['raiffeisen']
for companie in companies:
    print('!!!!!!!!!!!!!!!!!')
    print(companie)
    print ('~~~~~~~~~~~~~~~~~')
    
    X, y = df_filter(_df = df, _tfs = tfs, corporation = companie)
    X4, y4 = df_filter(_df = df, _tfs = tfs4vec, corporation = companie)
    X_test, y_test = df_filter(_df = df_test, _tfs = tfs, corporation = companie)
    X4_test, y4_test = df_filter(_df = df_test, _tfs = tfs4vec, corporation = companie)
    
    index = int((X.shape[0] + X_test.shape[0]) * 0.2)
    if (index < X_test.shape[0]):
        X = np.vstack((X, X_test[index:]))
        X_test = X_test[:index]
        y = np.concatenate((y,y_test[index:]))
        y_test = y_test[:index]
        X4 = np.vstack((X4, X4_test[index:]))
        X4_test = X4_test[:index]
        y4 = np.concatenate((y4,y4_test[index:]))
        y4_test = y4_test[:index]
    
    print ('DATA SIZE: TRAIN = {0}, TEST= {1}'.format(X.shape[0], X_test.shape[0]))
    print ('Naive Bayes: ')
    start_time = time.time()
    model = MultinomialNB()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    t = int(time.time() - start_time)
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = MultinomialNB()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('SVM: ')
    start_time = time.time()
    model = SVC()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = SVC()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))  
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('SVM linear kernel: ')
    start_time = time.time()
    model = SVC(kernel = 'linear')
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model = SVC(kernel = 'linear')
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 10: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=10)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=10)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 5: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=5)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=5)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 3: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=3)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=3)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 7: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=7)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=7)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('kNN 30: ')
    start_time = time.time()
    model = KNeighborsClassifier(n_neighbors=30)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  KNeighborsClassifier(n_neighbors=30)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('Decision Tree: ')
    start_time = time.time()
    model = DecisionTreeClassifier()
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  DecisionTreeClassifier()
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('Decision Tree max depth = 5: ')
    start_time = time.time()
    model = DecisionTreeClassifier(max_depth = 5)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  DecisionTreeClassifier(max_depth = 5)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
    print ('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print ('AdaBoost DecisionTree max_depth = 2, n = 100: ')
    start_time = time.time()
    model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
    model.fit(X, y)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X_test)
    t = int(time.time() - start_time)
    print ('predict time = {0} {1}'.format(t / 60, t % 60))
    print ('f-macro: {0}'.format(f1_score(y_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y_test, y_predict, average = 'micro')))
    print('~~~~~count vectorizer~~~~~~')
    start_time = time.time()
    model =  AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=100,
    learning_rate=1)
    model.fit(X4, y4)
    t = int(time.time() - start_time)
    print ('fit time = {0} {1}'.format(t / 60, t % 60))
    start_time = time.time()
    y_predict = model.predict(X4_test)
    t = int(time.time() - start_time) 
    print ('predict time = {0} {1}'.format(t / 60, t % 60)) 
    print ('f-macro: {0}'.format(f1_score(y4_test, y_predict, average = 'macro')))
    print ('f-micro: {0}'.format(f1_score(y4_test, y_predict, average = 'micro')))
